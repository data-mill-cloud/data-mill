# %%
import pyspark
sc = pyspark.SparkContext('local[*]')

# do something to prove it works
rdd = sc.parallelize(range(1000))
rdd.takeSample(False, 5)
# Out:
# [239, 887, 870, 719, 41]

# %% [markdown]
# More at https://jupyter-docker-stacks.readthedocs.io/en/latest/using/specifics.html#apache-spark
